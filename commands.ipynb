# %%
models_to_try = ["NCSF", "NSF", "SOSPF", "CNF", "UNAF"]

model_sizes = {

    "S": [3, "128,128,128"],
     "M": [3, "256,256,256"],
     "L": [5, "128,128,128"],
    "XL": [5, "256,256,256"]

}
transforms_to_try = [3, 5]
hidden_features_to_try = ["128,128,128"]

num_epochs = 1000
name = "test"

for m in models_to_try:
    for ms in model_sizes.keys():
        t = model_sizes[ms][0]
        hs = model_sizes[ms][1]
        command = f"python run_zuko.py --ZUKO_ID {m} --NUM_EPOCHS {num_epochs} --TRANSFORMS {t} --HIDDEN_FEATURES {hf} --FREQS {t} --TRAIN_FLOW --EVAL_FLOW --NAME {ms}"
        print(command)
# Out:
# python run_zuko.py --ZUKO_ID NSCF --NUM_EPOCHS 1000 --TRANSFORMS 3 --HIDDEN_FEATURES 128,128,128 --FREQS 3 --TRAIN_FLOW --EVAL_FLOW --NAME S
# python run_zuko.py --ZUKO_ID NSCF --NUM_EPOCHS 1000 --TRANSFORMS 3 --HIDDEN_FEATURES 128,128,128 --FREQS 3 --TRAIN_FLOW --EVAL_FLOW --NAME M
# python run_zuko.py --ZUKO_ID NSCF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5 --TRAIN_FLOW --EVAL_FLOW --NAME L
# python run_zuko.py --ZUKO_ID NSCF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5 --TRAIN_FLOW --EVAL_FLOW --NAME XL
# python run_zuko.py --ZUKO_ID NSF --NUM_EPOCHS 1000 --TRANSFORMS 3 --HIDDEN_FEATURES 128,128,128 --FREQS 3 --TRAIN_FLOW --EVAL_FLOW --NAME S
# python run_zuko.py --ZUKO_ID NSF --NUM_EPOCHS 1000 --TRANSFORMS 3 --HIDDEN_FEATURES 128,128,128 --FREQS 3 --TRAIN_FLOW --EVAL_FLOW --NAME M
# python run_zuko.py --ZUKO_ID NSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5 --TRAIN_FLOW --EVAL_FLOW --NAME L
# ...
