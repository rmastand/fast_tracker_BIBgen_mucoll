# %%
models_to_try = [
    "NCSF", 
    #"NSF", 
   # "SOSPF", 
   # "CNF",
   # "UNAF"
]



collections = {
    "OTBC": "OuterTrackerBarrelCollection",
    "ITBC": "InnerTrackerBarrelCollection",
    "VBC": "VertexBarrelCollection",
     "OTEC": "OuterTrackerEndcapCollection",
    "ITEC": "InnerTrackerEndcapCollection",
    "VEC": "VertexEndcapCollection",
    

}
    
model_sizes = {
   # "S": [3, "128,128,128"],
     "M": [5, "128,128,128"],
    # "L": [3, "256,256,256"],
    # "XL": [5, "256,256,256"]
}

model_sizes_CNF = {
    "S": [3, "128,128,128"],
    "M": [5, "256,256,256"],
    "L": [3, "256,256,256"],
    "XL": [5, "512,512,512"]

}




name = "test"

for m in models_to_try:
    for ms in model_sizes.keys():
        if m != "CNF":
            t = model_sizes[ms][0]
            hf = model_sizes[ms][1]
            num_epochs = 1000
            batch_size = 4096
        else:
            t = model_sizes_CNF[ms][0]
            hf = model_sizes_CNF[ms][1]
            num_epochs = 100
            batch_size = 4096
        for col in collections.keys():
            col_name = collections[col]
            command = f"python run_zuko.py --ZUKO_ID {m} --NUM_EPOCHS {num_epochs} --TRANSFORMS {t} --HIDDEN_FEATURES {hf} --FREQS {t} \
            --COLLECTION_LIST {col_name}   --TRAIN_FLOW   --EVAL_FLOW --NAME {col}_{ms}_{batch_size}_rphi --BATCH_SIZE {batch_size} --FEATURES rphi"
            print(command)
# Out:
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST OuterTrackerBarrelCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME OTBC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST InnerTrackerBarrelCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME ITBC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST VertexBarrelCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME VBC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST OuterTrackerEndcapCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME OTEC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST InnerTrackerEndcapCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME ITEC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
# python run_zuko.py --ZUKO_ID NCSF --NUM_EPOCHS 1000 --TRANSFORMS 5 --HIDDEN_FEATURES 128,128,128 --FREQS 5             --COLLECTION_LIST VertexEndcapCollection   --TRAIN_FLOW   --EVAL_FLOW --NAME VEC_M_4096_rphi --BATCH_SIZE 4096 --FEATURES rphi
